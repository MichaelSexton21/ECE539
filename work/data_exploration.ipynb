# %%
#jupyter notebook --notebook-dir=D:/

# %%
import numpy as np
from PIL import Image
from scipy.io import loadmat
img_dir = "../data/images/"
data_dir = "../data/"

# %%
img_num = "000001_1"
image = Image.open(img_dir+img_num+".jpg")
  
# summarize some details about the image
print(image.format)
print(image.size)
print(image.mode)
# Out:
# JPEG
# (1280, 1024)
# RGB

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1024 at 0x16F44A88B50>

# %%
np.array(image)
np.array(image).shape
# Out:
# (1024, 1280, 3)

# %%
data = loadmat(data_dir + "GPS_Long_Lat_Compass.mat")

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed May 28 20:48:40 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'GPS_Compass': array([[ 40.440309, -80.      , 115.74    ],
#         [ 40.440271, -80.0068  , 119.24    ],
#         [ 40.440229, -80.0067  , 118.96    ],
#         ...,
#         [ 40.730845, -74.001541,   2.49    ],
#         [ 40.730932, -74.00149 ,   2.35    ],
#         [ 40.731051, -74.00142 ,   2.21    ]])}

# %%
data["GPS_Compass"][0]
# Out:
# array([ 40.440309, -80.      , 115.74    ])
